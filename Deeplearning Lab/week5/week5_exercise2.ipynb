# %% [markdown]
# # 220968280 - Anirudh Swaminathan - DSE A2
#
# # Week 5 - Exercise 2

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import InputLayer, Flatten, Dense, SimpleRNN, LSTM
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/s_ani/Documents/textbooks/5thSem/Deeplearning/week5/BPD_Part_1_Victim_Based_Crime_Data.csv")

# %%
df['CrimeDate'] = pd.to_datetime(df['CrimeDate'], format="mixed")

# %%
larceny = df[df['CrimeCode'].str.startswith('6')]
burglary = df[df['CrimeCode'].str.startswith('5')]

LarcenyTs = larceny.groupby(larceny['CrimeDate'].dt.date).size()
BurglaryTs = burglary.groupby(burglary['CrimeDate'].dt.date).size()

LarcenyTs = LarcenyTs.reindex(pd.date_range(start='2014-01-01', end='2016-12-31'), fill_value=0)
BurglaryTs = BurglaryTs.reindex(pd.date_range(start='2014-01-01', end='2016-12-31'), fill_value=0)

# %%
def create_train_test_split(series, train_end='2015-12-31', test_start='2016-01-01'):
    train_data = series[series.index <= train_end].values
    test_data = series[series.index >= test_start].values
    return train_data, test_data

# %%
def reshape_data(data, timesteps):
    X, y = [], []
    for i in range(len(data) - timesteps):
        X.append(data[i:i+timesteps])
        y.append(data[i+timesteps])
    return np.array(X), np.array(y)

# %%
def evaluate_model(model, X_test, y_test):
    predictions = model.predict(X_test)
    mape = mean_absolute_percentage_error(y_test, predictions)
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    return mape, rmse, predictions

# %%
def plot_results(y_test, predictions, title):
    plt.figure(figsize=(10, 6))
    plt.plot(y_test, label="Actual")
    plt.plot(predictions, label="Predicted")
    plt.title(title)
    plt.xlabel("Days")
    plt.ylabel("Number of Crimes")
    plt.legend()
    plt.show()

# %%
timesteps = 30

# %%
larceny_train, larceny_test = create_train_test_split(LarcenyTs)
burglary_train, burglary_test = create_train_test_split(BurglaryTs)

larceny_X_train, larceny_y_train = reshape_data(larceny_train, timesteps)
larceny_X_test, larceny_y_test = reshape_data(larceny_test, timesteps)
burglary_X_train, burglary_y_train = reshape_data(burglary_train, timesteps)
burglary_X_test, burglary_y_test = reshape_data(burglary_test, timesteps)

# %%
larceny_X_train = np.expand_dims(larceny_X_train, -1)
larceny_X_test = np.expand_dims(larceny_X_test, -1)

burglary_X_train = np.expand_dims(burglary_X_train, -1)
burglary_X_test = np.expand_dims(burglary_X_test, -1)

# %%
def build_rnn_model(input_shape):
    model = Sequential([
        InputLayer(input_shape=input_shape),
        SimpleRNN(64, activation='relu', return_sequences=True),
        SimpleRNN(64, activation='relu', return_sequences=True),
        SimpleRNN(64, activation='relu', return_sequences=True),
        SimpleRNN(64, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='mse')
    return model

def build_lstm_model(input_shape):
    model = Sequential([
        InputLayer(input_shape=input_shape),
        LSTM(64, activation='relu', return_sequences=True),
        LSTM(64, activation='relu', return_sequences=True),
        LSTM(64, activation='relu', return_sequences=True),
        LSTM(64, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='mse')
    return model

# %%
rnn_model_larceny = build_rnn_model(input_shape=(timesteps, 1))
rnn_model_larceny.fit(larceny_X_train, larceny_y_train, epochs=50, verbose=1)
larceny_rnn_mape, larceny_rnn_rmse, larceny_rnn_predictions = evaluate_model(rnn_model_larceny, larceny_X_test, larceny_y_test)
print(f"Larceny RNN - MAPE: {larceny_rnn_mape}, RMSE: {larceny_rnn_rmse}")
# Out:
# Epoch 1/50
# 22/22 [==============================] - 3s 15ms/step - loss: 558.4250
# Epoch 2/50
# 22/22 [==============================] - 0s 16ms/step - loss: 96.6558
# Epoch 3/50
# 22/22 [==============================] - 0s 14ms/step - loss: 91.9143
# Epoch 4/50
# 22/22 [==============================] - 0s 14ms/step - loss: 89.2979
# Epoch 5/50
# 22/22 [==============================] - 0s 14ms/step - loss: 87.6077
# Epoch 6/50
# 22/22 [==============================] - 0s 15ms/step - loss: 87.8313
# Epoch 7/50
# 22/22 [==============================] - 0s 15ms/step - loss: 86.6614
# Epoch 8/50
# 22/22 [==============================] - 0s 15ms/step - loss: 87.8293
# Epoch 9/50
# 22/22 [==============================] - 0s 15ms/step - loss: 86.0556
# Epoch 10/50
# 22/22 [==============================] - 0s 14ms/step - loss: 90.2177
# Epoch 11/50
# 22/22 [==============================] - 0s 14ms/step - loss: 87.4966
# Epoch 12/50
# 22/22 [==============================] - 0s 14ms/step - loss: 85.7697
# Epoch 13/50
# 22/22 [==============================] - 0s 13ms/step - loss: 86.0960
# Epoch 14/50
# 22/22 [==============================] - 0s 14ms/step - loss: 94.9667
# Epoch 15/50
# 22/22 [==============================] - 0s 13ms/step - loss: 90.5309
# Epoch 16/50
# 22/22 [==============================] - 0s 13ms/step - loss: 92.5693
# Epoch 17/50
# 22/22 [==============================] - 0s 15ms/step - loss: 101.7065
# Epoch 18/50
# 22/22 [==============================] - 0s 15ms/step - loss: 88.2635
# Epoch 19/50
# 22/22 [==============================] - 0s 15ms/step - loss: 85.6242
# Epoch 20/50
# 22/22 [==============================] - 0s 14ms/step - loss: 89.5698
# Epoch 21/50
# 22/22 [==============================] - 0s 14ms/step - loss: 86.2200
# Epoch 22/50
# 22/22 [==============================] - 0s 18ms/step - loss: 84.3069
# Epoch 23/50
# 22/22 [==============================] - 0s 21ms/step - loss: 86.0375
# Epoch 24/50
# 22/22 [==============================] - 1s 23ms/step - loss: 82.6542
# Epoch 25/50
# 22/22 [==============================] - 0s 19ms/step - loss: 81.1609
# Epoch 26/50
# 22/22 [==============================] - 0s 19ms/step - loss: 81.2912
# Epoch 27/50
# 22/22 [==============================] - 0s 18ms/step - loss: 78.3181
# Epoch 28/50
# 22/22 [==============================] - 0s 18ms/step - loss: 79.5235
# Epoch 29/50
# 22/22 [==============================] - 0s 19ms/step - loss: 79.5385
# Epoch 30/50
# 22/22 [==============================] - 0s 18ms/step - loss: 80.1301
# Epoch 31/50
# 22/22 [==============================] - 0s 17ms/step - loss: 86.1803
# Epoch 32/50
# 22/22 [==============================] - 0s 20ms/step - loss: 79.1651
# Epoch 33/50
# 22/22 [==============================] - 0s 21ms/step - loss: 75.4717
# Epoch 34/50
# 22/22 [==============================] - 0s 18ms/step - loss: 77.7065
# Epoch 35/50
# 22/22 [==============================] - 0s 14ms/step - loss: 73.8018
# Epoch 36/50
# 22/22 [==============================] - 0s 14ms/step - loss: 81.7545
# Epoch 37/50
# 22/22 [==============================] - 0s 20ms/step - loss: 75.3686
# Epoch 38/50
# 22/22 [==============================] - 0s 20ms/step - loss: 71.3942
# Epoch 39/50
# 22/22 [==============================] - 0s 17ms/step - loss: 74.1255
# Epoch 40/50
# 22/22 [==============================] - 0s 17ms/step - loss: 69.7937
# Epoch 41/50
# 22/22 [==============================] - 0s 15ms/step - loss: 68.0639
# Epoch 42/50
# 22/22 [==============================] - 0s 19ms/step - loss: 71.4724
# Epoch 43/50
# 22/22 [==============================] - 0s 14ms/step - loss: 66.1481
# Epoch 44/50
# 22/22 [==============================] - 0s 13ms/step - loss: 67.7297
# Epoch 45/50
# 22/22 [==============================] - 0s 16ms/step - loss: 74.5178
# Epoch 46/50
# 22/22 [==============================] - 0s 18ms/step - loss: 69.4715
# Epoch 47/50
# 22/22 [==============================] - 0s 18ms/step - loss: 66.5217
# Epoch 48/50
# 22/22 [==============================] - 0s 18ms/step - loss: 61.1497
# Epoch 49/50
# 22/22 [==============================] - 0s 21ms/step - loss: 61.5612
# Epoch 50/50
# 22/22 [==============================] - 0s 17ms/step - loss: 60.7030
# 11/11 [==============================] - 0s 6ms/step
# Larceny RNN - MAPE: 6023851537084611.0, RMSE: 9.766712963058968

# %%
plot_results(larceny_y_test, larceny_rnn_predictions, "RNN Model - Larceny Crimes")

# %%
rnn_model_burglary = build_rnn_model(input_shape=(timesteps, 1))
rnn_model_burglary.fit(burglary_X_train, burglary_y_train, epochs=50, verbose=1)
burglary_rnn_mape, burglary_rnn_rmse, burglary_rnn_predictions = evaluate_model(rnn_model_burglary, burglary_X_test, burglary_y_test)
print(f"Burglary RNN - MAPE: {burglary_rnn_mape}, RMSE: {burglary_rnn_rmse}")
# Out:
# Epoch 1/50
# 22/22 [==============================] - 8s 20ms/step - loss: 198.1566
# Epoch 2/50
# 22/22 [==============================] - 0s 16ms/step - loss: 103.9823
# Epoch 3/50
# 22/22 [==============================] - 0s 15ms/step - loss: 91.7723
# Epoch 4/50
# 22/22 [==============================] - 0s 15ms/step - loss: 89.3481
# Epoch 5/50
# 22/22 [==============================] - 0s 14ms/step - loss: 88.6991
# Epoch 6/50
# 22/22 [==============================] - 0s 16ms/step - loss: 86.7374
# Epoch 7/50
# 22/22 [==============================] - 0s 15ms/step - loss: 86.1462
# Epoch 8/50
# 22/22 [==============================] - 0s 14ms/step - loss: 87.1134
# Epoch 9/50
# 22/22 [==============================] - 0s 15ms/step - loss: 83.5328
# Epoch 10/50
# 22/22 [==============================] - 0s 15ms/step - loss: 85.9925
# Epoch 11/50
# 22/22 [==============================] - 0s 15ms/step - loss: 88.6950
# Epoch 12/50
# 22/22 [==============================] - 0s 17ms/step - loss: 82.9389
# Epoch 13/50
# 22/22 [==============================] - 0s 17ms/step - loss: 81.7469
# Epoch 14/50
# 22/22 [==============================] - 0s 17ms/step - loss: 84.6131
# Epoch 15/50
# 22/22 [==============================] - 0s 22ms/step - loss: 83.1448
# Epoch 16/50
# 22/22 [==============================] - 0s 20ms/step - loss: 83.4279
# Epoch 17/50
# 22/22 [==============================] - 1s 23ms/step - loss: 86.1999
# Epoch 18/50
# 22/22 [==============================] - 0s 21ms/step - loss: 84.5495
# Epoch 19/50
# 22/22 [==============================] - 0s 21ms/step - loss: 81.1353
# Epoch 20/50
# 22/22 [==============================] - 0s 20ms/step - loss: 82.2973
# Epoch 21/50
# 22/22 [==============================] - 0s 17ms/step - loss: 79.8958
# Epoch 22/50
# 22/22 [==============================] - 0s 14ms/step - loss: 79.4223
# Epoch 23/50
# 22/22 [==============================] - 0s 14ms/step - loss: 79.8353
# Epoch 24/50
# 22/22 [==============================] - 0s 16ms/step - loss: 80.6852
# Epoch 25/50
# 22/22 [==============================] - 0s 18ms/step - loss: 76.5729
# Epoch 26/50
# 22/22 [==============================] - 0s 15ms/step - loss: 75.0609
# Epoch 27/50
# 22/22 [==============================] - 0s 16ms/step - loss: 75.7232
# Epoch 28/50
# 22/22 [==============================] - 0s 15ms/step - loss: 82.3266
# Epoch 29/50
# 22/22 [==============================] - 0s 18ms/step - loss: 75.5283
# Epoch 30/50
# 22/22 [==============================] - 0s 20ms/step - loss: 75.1592
# Epoch 31/50
# 22/22 [==============================] - 0s 20ms/step - loss: 77.8979
# Epoch 32/50
# 22/22 [==============================] - 0s 20ms/step - loss: 75.4794
# Epoch 33/50
# 22/22 [==============================] - 0s 20ms/step - loss: 72.1589
# Epoch 34/50
# 22/22 [==============================] - 0s 22ms/step - loss: 72.1635
# Epoch 35/50
# 22/22 [==============================] - 0s 21ms/step - loss: 86.2662
# Epoch 36/50
# 22/22 [==============================] - 0s 18ms/step - loss: 78.8223
# Epoch 37/50
# 22/22 [==============================] - 0s 17ms/step - loss: 72.4927
# Epoch 38/50
# 22/22 [==============================] - 0s 14ms/step - loss: 71.4032
# Epoch 39/50
# 22/22 [==============================] - 0s 14ms/step - loss: 72.7178
# Epoch 40/50
# 22/22 [==============================] - 0s 16ms/step - loss: 66.8278
# Epoch 41/50
# 22/22 [==============================] - 0s 15ms/step - loss: 63.7708
# Epoch 42/50
# 22/22 [==============================] - 0s 15ms/step - loss: 62.3330
# Epoch 43/50
# 22/22 [==============================] - 0s 15ms/step - loss: 65.5456
# Epoch 44/50
# 22/22 [==============================] - 0s 15ms/step - loss: 58.8967
# Epoch 45/50
# 22/22 [==============================] - 0s 22ms/step - loss: 50.5260
# Epoch 46/50
# 22/22 [==============================] - 0s 22ms/step - loss: 54.9446
# Epoch 47/50
# 22/22 [==============================] - 0s 20ms/step - loss: 57.9969
# Epoch 48/50
# 22/22 [==============================] - 0s 20ms/step - loss: 81.3362
# Epoch 49/50
# 22/22 [==============================] - 0s 20ms/step - loss: 72.6739
# Epoch 50/50
# 22/22 [==============================] - 1s 53ms/step - loss: 57.7812
# 11/11 [==============================] - 1s 15ms/step
# Burglary RNN - MAPE: 2082523843108474.2, RMSE: 10.386269539139551

# %%
plot_results(burglary_y_test, burglary_rnn_predictions, "RNN Model - Burglary Crimes")

# %%
lstm_model_larceny = build_lstm_model(input_shape=(timesteps, 1))
lstm_model_larceny.fit(larceny_X_train, larceny_y_train, epochs=50, verbose=1)
larceny_lstm_mape, larceny_lstm_rmse, larceny_lstm_predictions = evaluate_model(lstm_model_larceny, larceny_X_test, larceny_y_test)
print(f"Larceny LSTM - MAPE: {larceny_lstm_mape}, RMSE: {larceny_lstm_rmse}")
# Out:
# Epoch 1/50
# 22/22 [==============================] - 4s 42ms/step - loss: 1415.0955
# Epoch 2/50
# 22/22 [==============================] - 1s 43ms/step - loss: 454.6761
# Epoch 3/50
# 22/22 [==============================] - 1s 40ms/step - loss: 261.6759
# Epoch 4/50
# 22/22 [==============================] - 1s 40ms/step - loss: 191.6004
# Epoch 5/50
# 22/22 [==============================] - 1s 43ms/step - loss: 138.6228
# Epoch 6/50
# 22/22 [==============================] - 1s 38ms/step - loss: 122.7383
# Epoch 7/50
# 22/22 [==============================] - 1s 42ms/step - loss: 114.7405
# Epoch 8/50
# 22/22 [==============================] - 1s 59ms/step - loss: 109.3136
# Epoch 9/50
# 22/22 [==============================] - 1s 61ms/step - loss: 96.2219
# Epoch 10/50
# 22/22 [==============================] - 1s 52ms/step - loss: 131.7214
# Epoch 11/50
# 22/22 [==============================] - 1s 40ms/step - loss: 147.5348
# Epoch 12/50
# 22/22 [==============================] - 1s 54ms/step - loss: 141.0677
# Epoch 13/50
# 22/22 [==============================] - 1s 59ms/step - loss: 122.8574
# Epoch 14/50
# 22/22 [==============================] - 1s 41ms/step - loss: 121.2964
# Epoch 15/50
# 22/22 [==============================] - 1s 57ms/step - loss: 113.5855
# Epoch 16/50
# 22/22 [==============================] - 1s 42ms/step - loss: 123.0693
# Epoch 17/50
# 22/22 [==============================] - 1s 40ms/step - loss: 110.5815
# Epoch 18/50
# 22/22 [==============================] - 1s 46ms/step - loss: 108.8266
# Epoch 19/50
# 22/22 [==============================] - 1s 63ms/step - loss: 97.7910
# Epoch 20/50
# 22/22 [==============================] - 1s 45ms/step - loss: 96.0063
# Epoch 21/50
# 22/22 [==============================] - 1s 59ms/step - loss: 93.6625
# Epoch 22/50
# 22/22 [==============================] - 1s 49ms/step - loss: 92.8959
# Epoch 23/50
# 22/22 [==============================] - 1s 44ms/step - loss: 94.0509
# Epoch 24/50
# 22/22 [==============================] - 1s 49ms/step - loss: 96.0859
# Epoch 25/50
# 22/22 [==============================] - 1s 48ms/step - loss: 96.4679
# Epoch 26/50
# 22/22 [==============================] - 1s 38ms/step - loss: 97.3693
# Epoch 27/50
# 22/22 [==============================] - 1s 51ms/step - loss: 92.4859
# Epoch 28/50
# 22/22 [==============================] - 1s 48ms/step - loss: 90.6711
# Epoch 29/50
# 22/22 [==============================] - 1s 41ms/step - loss: 91.5969
# Epoch 30/50
# 22/22 [==============================] - 1s 47ms/step - loss: 89.6820
# Epoch 31/50
# 22/22 [==============================] - 1s 45ms/step - loss: 108.1120
# Epoch 32/50
# 22/22 [==============================] - 1s 39ms/step - loss: 121.7344
# Epoch 33/50
# 22/22 [==============================] - 1s 41ms/step - loss: 149.7697
# Epoch 34/50
# 22/22 [==============================] - 1s 47ms/step - loss: 203.1426
# Epoch 35/50
# 22/22 [==============================] - 1s 54ms/step - loss: 176.6720
# Epoch 36/50
# 22/22 [==============================] - 1s 63ms/step - loss: 178.1546
# Epoch 37/50
# 22/22 [==============================] - 1s 45ms/step - loss: 131.2419
# Epoch 38/50
# 22/22 [==============================] - 1s 40ms/step - loss: 113.7982
# Epoch 39/50
# 22/22 [==============================] - 1s 40ms/step - loss: 212.5173
# Epoch 40/50
# 22/22 [==============================] - 1s 62ms/step - loss: 7474694.5000
# Epoch 41/50
# 22/22 [==============================] - 3s 160ms/step - loss: 118709064.0000
# Epoch 42/50
# 22/22 [==============================] - 2s 86ms/step - loss: 36531244.0000
# Epoch 43/50
# 22/22 [==============================] - 2s 85ms/step - loss: 4849267.0000
# Epoch 44/50
# 22/22 [==============================] - 2s 83ms/step - loss: 974643.8125
# Epoch 45/50
# 22/22 [==============================] - 2s 85ms/step - loss: 13187.7676
# Epoch 46/50
# 22/22 [==============================] - 2s 89ms/step - loss: 1362.4653
# Epoch 47/50
# 22/22 [==============================] - 2s 93ms/step - loss: 511.1349
# Epoch 48/50
# 22/22 [==============================] - 2s 89ms/step - loss: 357.4140
# Epoch 49/50
# 22/22 [==============================] - 2s 90ms/step - loss: 346.3929
# Epoch 50/50
# 22/22 [==============================] - 2s 89ms/step - loss: 342.1363
# 11/11 [==============================] - 2s 38ms/step
# Larceny LSTM - MAPE: 2.214832738754326e+16, RMSE: 22.608181112679674

# %%
plot_results(larceny_y_test, larceny_lstm_predictions, "LSTM Model - Larceny Crimes")

# %%
lstm_model_burglary = build_lstm_model(input_shape=(timesteps, 1))
lstm_model_burglary.fit(burglary_X_train, burglary_y_train, epochs=50, verbose=1)
burglary_lstm_mape, burglary_lstm_rmse, burglary_lstm_predictions = evaluate_model(lstm_model_burglary, burglary_X_test, burglary_y_test)
print(f"Burglary LSTM - MAPE: {burglary_lstm_mape}, RMSE: {burglary_lstm_rmse}")
# Out:
# Epoch 1/50
# 22/22 [==============================] - 4s 39ms/step - loss: 664.7211
# Epoch 2/50
# 22/22 [==============================] - 1s 39ms/step - loss: 1072.2954
# Epoch 3/50
# 22/22 [==============================] - 1s 41ms/step - loss: 1620.5853
# Epoch 4/50
# 22/22 [==============================] - 1s 40ms/step - loss: 248.8538
# Epoch 5/50
# 22/22 [==============================] - 1s 40ms/step - loss: 193.8234
# Epoch 6/50
# 22/22 [==============================] - 1s 39ms/step - loss: 204.2169
# Epoch 7/50
# 22/22 [==============================] - 1s 40ms/step - loss: 209.5695
# Epoch 8/50
# 22/22 [==============================] - 1s 42ms/step - loss: 237.6503
# Epoch 9/50
# 22/22 [==============================] - 1s 38ms/step - loss: 196.5790
# Epoch 10/50
# 22/22 [==============================] - 1s 39ms/step - loss: 142.6198
# Epoch 11/50
# 22/22 [==============================] - 1s 48ms/step - loss: 140.2634
# Epoch 12/50
# 22/22 [==============================] - 1s 44ms/step - loss: 126.6928
# Epoch 13/50
# 22/22 [==============================] - 1s 53ms/step - loss: 202.1869
# Epoch 14/50
# 22/22 [==============================] - 1s 49ms/step - loss: 129.7473
# Epoch 15/50
# 22/22 [==============================] - 1s 41ms/step - loss: 141.8368
# Epoch 16/50
# 22/22 [==============================] - 1s 38ms/step - loss: 119.6155
# Epoch 17/50
# 22/22 [==============================] - 1s 39ms/step - loss: 114.9612
# Epoch 18/50
# 22/22 [==============================] - 1s 39ms/step - loss: 124.5881
# Epoch 19/50
# 22/22 [==============================] - 1s 40ms/step - loss: 117.3904
# Epoch 20/50
# 22/22 [==============================] - 1s 43ms/step - loss: 130.2644
# Epoch 21/50
# 22/22 [==============================] - 1s 49ms/step - loss: 99.8673
# Epoch 22/50
# 22/22 [==============================] - 1s 40ms/step - loss: 105.8941
# Epoch 23/50
# 22/22 [==============================] - 1s 44ms/step - loss: 125.3860
# Epoch 24/50
# 22/22 [==============================] - 1s 40ms/step - loss: 119.0255
# Epoch 25/50
# 22/22 [==============================] - 1s 41ms/step - loss: 111.0326
# Epoch 26/50
# 22/22 [==============================] - 1s 48ms/step - loss: 104.6700
# Epoch 27/50
# 22/22 [==============================] - 1s 64ms/step - loss: 101.8953
# Epoch 28/50
# 22/22 [==============================] - 1s 58ms/step - loss: 97.0081
# Epoch 29/50
# 22/22 [==============================] - 1s 61ms/step - loss: 96.0132
# Epoch 30/50
# 22/22 [==============================] - 1s 38ms/step - loss: 96.2572
# Epoch 31/50
# 22/22 [==============================] - 1s 40ms/step - loss: 95.9156
# Epoch 32/50
# 22/22 [==============================] - 1s 40ms/step - loss: 95.1176
# Epoch 33/50
# 22/22 [==============================] - 1s 41ms/step - loss: 93.6625
# Epoch 34/50
# 22/22 [==============================] - 1s 39ms/step - loss: 92.7958
# Epoch 35/50
# 22/22 [==============================] - 1s 48ms/step - loss: 92.0297
# Epoch 36/50
# 22/22 [==============================] - 1s 54ms/step - loss: 90.7569
# Epoch 37/50
# 22/22 [==============================] - 1s 48ms/step - loss: 91.5595
# Epoch 38/50
# 22/22 [==============================] - 1s 46ms/step - loss: 91.4663
# Epoch 39/50
# 22/22 [==============================] - 1s 46ms/step - loss: 89.0667
# Epoch 40/50
# 22/22 [==============================] - 1s 45ms/step - loss: 90.4416
# Epoch 41/50
# 22/22 [==============================] - 1s 42ms/step - loss: 89.1341
# Epoch 42/50
# 22/22 [==============================] - 1s 51ms/step - loss: 91.8554
# Epoch 43/50
# 22/22 [==============================] - 1s 54ms/step - loss: 89.5406
# Epoch 44/50
# 22/22 [==============================] - 1s 44ms/step - loss: 89.0505
# Epoch 45/50
# 22/22 [==============================] - 1s 44ms/step - loss: 89.0381
# Epoch 46/50
# 22/22 [==============================] - 1s 41ms/step - loss: 87.0253
# Epoch 47/50
# 22/22 [==============================] - 1s 44ms/step - loss: 88.2306
# Epoch 48/50
# 22/22 [==============================] - 1s 40ms/step - loss: 84.9028
# Epoch 49/50
# 22/22 [==============================] - 1s 40ms/step - loss: 86.8073
# Epoch 50/50
# 22/22 [==============================] - 1s 41ms/step - loss: 85.4345
# 11/11 [==============================] - 1s 14ms/step
# Burglary LSTM - MAPE: 4304575514929054.5, RMSE: 10.227789957878663

# %%
plot_results(burglary_y_test, burglary_lstm_predictions, "LSTM Model - Burglary Crimes")

# %% [markdown]
# RNN models seems to perform better than the LSTM models for both cases.
#
# MAPE for all models was extremely high, RMSE was more reasonable.
