# %% [markdown]
# # 220968280 - Anirudh Swaminathan - DSE A2
#
# ## Week1_Q6

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import bokeh
import plotly

# %%
df1 = pd.DataFrame()
df1 = pd.read_csv('Data1.csv')
df2 = pd.read_excel('Data2.xlsx')

# %% [markdown]
# ### a. Scatter plots with coloured points and adjustable sizes using columns (1) col1, col2 and (2) col3, col4 (3) col5, col6.

# %%
plt.scatter(df1['Pregnancies'], df1['Glucose'], color='green')
plt.title('Pregnancies vs Glucose')
# Out:
# Text(0.5, 1.0, 'Pregnancies vs Glucose')

# %%
plt.scatter(df1['BloodPressure'], df1['SkinThickness'], color='red')
plt.title('BloodPressure vs SkinThickness')
# Out:
# Text(0.5, 1.0, 'BloodPressure vs SkinThickness')

# %%
plt.scatter(df1['Insulin'], df1['BMI'], color='blue')
plt.title('Insulin vs BMI')
# Out:
# Text(0.5, 1.0, 'Insulin vs BMI')

# %%
plt.scatter(df2['BLOCKS'], df2['VILLAGES'], color='green')
plt.title('Blocks vs Villages')
# Out:
# Text(0.5, 1.0, 'Blocks vs Villages')

# %%
plt.scatter(df2['CLUSTERS'], df2['TOTPOPULAT'], color='red')
plt.title('Clusters vs Total Population')
# Out:
# Text(0.5, 1.0, 'Clusters vs Total Population')

# %% [markdown]
# ### b. Line charts for columns (1) col1, col2 (2) col3, col4 (3) col5, col6

# %%
sns.lineplot(x=df1['Pregnancies'], y=df1['Glucose'])
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Glucose'>

# %%
sns.lineplot(x=df1['BloodPressure'], y=df1['SkinThickness'])
# Out:
# <Axes: xlabel='BloodPressure', ylabel='SkinThickness'>

# %%
sns.lineplot(x=df1['Insulin'], y=df1['BMI'])
# Out:
# <Axes: xlabel='Insulin', ylabel='BMI'>

# %%
sns.lineplot(x=df2['BLOCKS'], y=df2['VILLAGES'])
# Out:
# <Axes: xlabel='BLOCKS', ylabel='VILLAGES'>

# %%
sns.lineplot(x=df2['CLUSTERS'], y=df2['TOTPOPULAT'])
# Out:
# <Axes: xlabel='CLUSTERS', ylabel='TOTPOPULAT'>

# %% [markdown]
# ### c. Bar charts representing columns (1) col1, col2 (2) col3, col4 (3) col5, col6.

# %%
plt.bar(df1['Pregnancies'], df1['Glucose'])
# Out:
# <BarContainer object of 768 artists>

# %%
plt.bar(df1['BloodPressure'], df1['SkinThickness'])
# Out:
# <BarContainer object of 768 artists>

# %%
plt.bar(df1['Insulin'], df1['BMI'])
# Out:
# <BarContainer object of 768 artists>

# %%
plt.bar(df2['BLOCKS'], df2['VILLAGES'])
# Out:
# <BarContainer object of 32 artists>

# %%
plt.bar(df2['CLUSTERS'], df2['TOTPOPULAT'])
# Out:
# <BarContainer object of 32 artists>

# %% [markdown]
# ### d. Histograms to depict the dataset's distribution.

# %%
sns.histplot(df1)
# Out:
# <Axes: ylabel='Count'>

# %%
t2 = df2.drop('STATNAME', axis=1)
sns.histplot(t2.drop('DISTNAME', axis=1))
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ### e. Employ Bokeh for interactive data visualization.

# %%
import bokeh.plotting as bp
from bokeh.io import output_notebook

fig = bp.figure()
fig.scatter(
    x=df1['Pregnancies'],
    y=df1['Glucose'],
    alpha = 0.5
)
output_notebook()
bp.show(fig)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d342d0c3-0d50-46fb-a1b4-e6c663a2cac4">Loading BokehJS ...</span>
#     </div>
#   <div id="add1b5bb-6307-4576-8081-7efa0347e5b0" data-root-id="p1001" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, show
from bokeh.models import HoverTool
from bokeh.io import output_notebook
col1 = 'BLOCKS'
col2 = 'VILLAGES'
output_notebook()
p = figure(title=f'Interactive Scatter Plot of {col1} vs {col2}', 
           x_axis_label=col1, y_axis_label=col2,
           tools='pan,box_zoom,reset,hover,save')
scatter = p.circle(x=df2[col1], y=df2[col2], size=8, color='red', alpha=0.7)
hover = HoverTool()
hover.tooltips = [(f'{col1}', f'@{col1}'), (f'{col2}', f'@{col2}')]
p.add_tools(hover)
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ec4c270a-9bd1-4427-bc6e-3a24952248ae">Loading BokehJS ...</span>
#     </div>
#   <div id="b23d275c-c590-4485-accb-a5545453f46c" data-root-id="p1044" style="display: contents;"></div>

# %% [markdown]
# ### f. Utilize Bokeh's GUI features, including buttons, sliders, checkboxes, and radio buttons.

# %%
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.models.widgets import Button, Slider, CheckboxButtonGroup, RadioButtonGroup
from bokeh.io import output_file, show
import numpy as np

# %%
plot = figure(title='Bokeh GUI Features Example', width=600, height=400)
x = np.linspace(0, 10, 100)
y = np.sin(x)
line = plot.line(x, y, line_width=2)
checkbox_group = CheckboxButtonGroup(labels=['Show/Hide Line'], active=[0])
radio_button_group = RadioButtonGroup(labels=['Red', 'Green', 'Blue'], active=0)
button = Button(label='Click Me')
slider = Slider(start=0.1, end=2, value=1, step=0.1, title='Line Width')
def update(attrname, old, new):

    line.visible = 0 in checkbox_group.active
    
 
    colors = ['red', 'green', 'blue']
    line.glyph.line_color = colors[radio_button_group.active]
    

    line.glyph.line_width = slider.value


checkbox_group.on_change('active', update)
radio_button_group.on_change('active', update)
slider.on_change('value', update)


layout = column(checkbox_group, radio_button_group, button, slider, plot)

output_file('bokeh_gui_example.html')
show(layout)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html
#   <div id="eba420c5-414c-418f-bd8c-e79199eaa350" data-root-id="p1176" style="display: contents;"></div>
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# ...

# %%
import pandas as pd
from bokeh.io import curdoc
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, Button, Slider, CheckboxGroup, RadioGroup
from bokeh.layouts import column, row
source = ColumnDataSource(df2)
p = figure(title="Interactive Scatter Plot", x_axis_label='BLOCKS', y_axis_label='VILLAGES')
scatter = p.circle(x='BLOCKS', y='VILLAGES', source=source, size=8, color='blue', alpha=0.7)
hover = HoverTool()
hover.tooltips = [("BLOCKS", "@BLOCKS"), ("VILLAGES", "@VILLAGES")]
p.add_tools(hover)
button = Button(label="Randomize Data", button_type="success")
slider = Slider(title="Size", value=8, start=1, end=20, step=1)
checkbox_group = CheckboxGroup(labels=["Show Scatter Plot"], active=[0])
radio_group = RadioGroup(labels=["Blue", "Red"], active=0)
def update_plot():
    scatter.glyph.size = slider.value
button.on_click(update_plot)
slider.on_change('value', lambda attr, old, new: update_plot())
layout = column(
    row(button, slider),
    row(checkbox_group, radio_group),
    p
)
curdoc().add_root(layout)
show(layout, notebook_handle=True)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html
#   <div id="af0d7cb9-f029-425b-af64-58caa1b26951" data-root-id="p1234" style="display: contents;"></div>
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# ...

# %% [markdown]
# ### g. Employ Plotly to create a dropdown menu.

# %%
import plotly.graph_objects as go
fig = go.Figure()

scatter = go.Scatter(
    x=df1['Glucose'],
    y=df1['BloodPressure'],
    mode='markers',
    marker=dict(color='blue'),
    name='Glucose vs. Blood Pressure'
)
fig.add_trace(scatter)


dropdown_options = [
    {'label': 'Glucose vs. Blood Pressure', 'method': 'update', 'args': [{'visible': [True]}, {'title': 'Glucose vs. Blood Pressure'}]},
    
]

fig.update_layout(
    updatemenus=[
        {
            'buttons': dropdown_options,
            'direction': 'down',
            'showactive': True,
        }
    ]
)
fig.show()

# %%
import plotly.graph_objects as go
col1 = 'BLOCKS'
col2 = 'VILLAGES'
dropdown_menu = [{'label': col, 'method': 'update', 'args': [{'x': [df2[col]], 'y': [df2[col]], 'text': [df2[col]], 'marker': {'size': 8}, 'mode': 'markers', 'name': col}]} for col in df2.columns]
scatter = go.Scatter(x=df2[col1], y=df2[col2], text=df2[col1], mode='markers', marker=dict(size=8), name=col1)
layout = go.Layout(title=f'Interactive Scatter Plot of {col1} vs {col2}',
                   xaxis=dict(title=col1),
                   yaxis=dict(title=col2),
                   updatemenus=[{'buttons': dropdown_menu, 'direction': 'down', 'showactive': True}])
fig = go.Figure(data=[scatter], layout=layout)
fig.show()

# %% [markdown]
# ### h. Develop custom action buttons using Plotly

# %%
fig = go.Figure()

scatter = go.Scatter(
    x=df1['Glucose'],
    y=df1['BMI'],
    mode='markers',
    marker=dict(color='green'),
    name='Glucose vs. BMI'
)
fig.add_trace(scatter)


buttons = [
    dict(label='Update Marker Color',
         method='update',
         args=[{'marker.color': 'blue'}, {'title': 'Glucose vs. BMI (Marker Color: blue)'}]),
]
fig.update_layout(
    updatemenus=[
        {
            'buttons': buttons,
            'direction': 'down',
            'showactive': True,
            'x': 0.1,
            'xanchor': 'left',
            'y': 1.1,
            'yanchor': 'top'
        },
    ]
)
fig.show()

# %%
fig = go.Figure()

scatter = go.Scatter(
    x=df2['DISTCD'],
    y=df2['TOTPOPULAT'],
    mode='markers',
    marker=dict(color='green'),
    name='DISTCD vs. TOTAL POPULATION'
)
fig.add_trace(scatter)


buttons = [
    dict(label='Update Marker Color',
         method='update',
         args=[{'marker.color': 'blue'}, {'title': 'DISTCD vs. TOTAL POPULATION (Marker Color: blue)'}]),
]
fig.update_layout(
    updatemenus=[
        {
            'buttons': buttons,
            'direction': 'down',
            'showactive': True,
            'x': 0.1,
            'xanchor': 'left',
            'y': 1.1,
            'yanchor': 'top'
        },
    ]
)
fig.show()
